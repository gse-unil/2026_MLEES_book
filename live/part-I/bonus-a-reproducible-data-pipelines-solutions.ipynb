# %% [markdown]
# > Notebook-friendly copy of `part-I/bonus-a-reproducible-data-pipelines-solutions.ipynb`, generated by `tools/make_live.py`. Edit the book notebook, not this file.

# %% [markdown]
# # Solutions

# %% [markdown]
# **ℹ️ Reference solutions**
#
# Worked solutions for the short exercises in [bonus-a-reproducible-data-pipelines-exercises.ipynb](bonus-a-reproducible-data-pipelines-exercises.ipynb).

# %% [markdown]
# ## Exercise 1: CSV versus parquet
#
# Build a 1000-row DataFrame with a `time` column (`pd.date_range`, hourly) and a numeric column. Write it to CSV and to parquet, print both file sizes, and confirm that parquet preserves the datetime dtype on read-back.

# %%
import pandas as pd
from pathlib import Path
Path("_files").mkdir(exist_ok=True)
df = pd.DataFrame({"time": pd.date_range("2024-01-01", periods=1000, freq="h"),
                   "value": range(1000)})
df.to_csv("_files/e.csv", index=False)
df.to_parquet("_files/e.parquet")
print("csv:", Path("_files/e.csv").stat().st_size, "| parquet:", Path("_files/e.parquet").stat().st_size)
print(pd.read_parquet("_files/e.parquet").dtypes.to_dict())   # time stays datetime64

# %% [markdown]
# ## Exercise 2: netCDF versus zarr
#
# Build a small xarray Dataset with a monthly time coordinate. Write it to netCDF and to zarr, then confirm that the netCDF output is a file and the zarr output is a directory.

# %%
import numpy as np
import pandas as pd
import xarray as xr
from pathlib import Path
Path("_files").mkdir(exist_ok=True)
ds = xr.Dataset({"t2m": (("time",), np.arange(12.0))},
                coords={"time": pd.date_range("2024-01-01", periods=12, freq="MS")})
ds.to_netcdf("_files/e.nc")
ds.to_zarr("_files/e.zarr", mode="w")
print(Path("_files/e.nc").is_file(), Path("_files/e.zarr").is_dir())

# %% [markdown]
# ## Exercise 3: Hashing for integrity
#
# Write a short text file, copy it to a second path, and use `pooch.file_hash` to confirm that identical content produces identical hashes.

# %%
import shutil
import pooch
from pathlib import Path
Path("_files").mkdir(exist_ok=True)
Path("_files/a.txt").write_text("reproducible data\n")
shutil.copy("_files/a.txt", "_files/b.txt")
print(pooch.file_hash("_files/a.txt") == pooch.file_hash("_files/b.txt"))   # True

# %% [markdown]
# ## Exercise 4: An idempotent fetch
#
# Using a local file as the "source", implement `fetch(expected_hash)` that copies the source into a cache path on a miss and skips on a hash match. Call it twice and show that the first call downloads and the second is a cache hit.

# %%
import shutil
import pooch
from pathlib import Path

source = Path("_files/src.csv"); source.parent.mkdir(exist_ok=True); source.write_text("x\n1\n2\n")
known = pooch.file_hash(source)
cache = Path("_files/cache_x/src.csv")
def fetch(expected):
    cache.parent.mkdir(exist_ok=True, parents=True)
    if cache.exists() and pooch.file_hash(cache) == expected:
        return "hit"
    shutil.copy(source, cache)
    return "downloaded"
print(fetch(known), fetch(known))   # downloaded, hit

# %% [markdown]
# ## Exercise 5: Fix the existence-only check
#
# A stale, truncated file sits in the cache. Write `fetch_verified(expected_hash)` that re-fetches from the source whenever the cached file is missing *or* its hash does not match, then returns the correct content.
#
# ```python
# source = Path("_files/src.csv"); source.write_text("x\n1\n2\n3\n")
# cache = Path("_files/c5/src.csv"); cache.parent.mkdir(exist_ok=True, parents=True)
# cache.write_text("x\n1\n")   # stale / truncated
# ```

# %%
import shutil
import pooch
from pathlib import Path
source = Path("_files/src.csv"); source.parent.mkdir(exist_ok=True); source.write_text("x\n1\n2\n3\n")
known = pooch.file_hash(source)
cache = Path("_files/c5/src.csv"); cache.parent.mkdir(exist_ok=True, parents=True)
cache.write_text("x\n1\n")   # stale / truncated
def fetch_verified(expected):
    if not (cache.exists() and pooch.file_hash(cache) == expected):
        shutil.copy(source, cache)
    return cache.read_text()
print(fetch_verified(known))   # the full, correct content

# %% [markdown]
# ## Exercise 6: A real pooch.retrieve call
#
# Write a `pooch.retrieve` call that fetches a CSV from a URL, pins it with a SHA256 `known_hash`, caches it in an OS-appropriate folder, and reads it with pandas.
#
# Use a file this book already ships, so the call actually runs:
#
# ```
# https://raw.githubusercontent.com/gse-unil/2026_MLEES_book/main/data/part-I/forest_fires.csv
# sha256:0d6586a1fa52f55bef48578aef14eb97273f1e9330e1a53423df497a77065253
# ```
#
# Then run the cell a second time and watch what it does *not* print. The first run downloads; the second finds the file in the cache, checks its hash, and returns the path without touching the network.

# %%
import pooch
import pandas as pd

# %%
path = pooch.retrieve(
    url="https://raw.githubusercontent.com/gse-unil/2026_MLEES_book/main/data/part-I/forest_fires.csv",
    known_hash="sha256:0d6586a1fa52f55bef48578aef14eb97273f1e9330e1a53423df497a77065253",
    fname="forest_fires.csv",
    path=pooch.os_cache("mlees"),      # ~/Library/Caches/mlees, %LOCALAPPDATA%\\mlees, ~/.cache/mlees
)
print(path)

# %%
data = pd.read_csv(path)
print(data.shape)

# Run this cell again: the "Downloading data from ..." line appears only the first time.
# pooch found the cached file, hashed it, matched it against known_hash, and returned the
# path -- which is the whole idempotent-fetch pattern in one call.
